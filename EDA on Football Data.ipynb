# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
player = pd.read_csv("players_20 (1).csv")
player.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for i in player.columns:
    print(i)
i.head()
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
player.shape
# Out:
# (18278, 104)

# %%
player["nationality"].value_counts()[:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(player['nationality'].value_counts()[0:5].keys()),list(player['nationality'].value_counts()[0:5]),color="g")
plt.show()

# %%
play_sal=player[["short_name",'wage_eur']]
play_sal.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
max_sal=play_sal.sort_values(by=["wage_eur"],ascending=False)
max_sal.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.bar(list(max_sal["short_name"])[:5],list(max_sal["wage_eur"][0:5]),color=['red','blue','green','grey','pink'])
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_6084\1682735065.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(max_sal["short_name"])[:5],list(max_sal["wage_eur"][0:5]),color=['red','blue','green','grey','pink'])

# %%
arg=player[player["nationality"]=='Argentina']
arg.head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
# 93     201399  https://sofifa.com/player/201399/mauro-icardi/...    M. Icardi
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 17  Sergio Leonel Agüero del Castillo   31  1988-06-02        173         70
# 23        Paulo Bruno Exequiel Dybala   25  1993-11-15        177         75
# 66    Ángel Fabián Di María Hernández   31  1988-02-14        180         69
# 93        Mauro Emanuel Icardi Rivero   26  1993-02-19        181         75
#
# ...

# %%
arg.sort_values(by=["height_cm"],ascending=False)[:5]
# Out:
#       sofifa_id                                         player_url  \
# 6542     223071  https://sofifa.com/player/223071/fernando-pell...
# 6067     222889  https://sofifa.com/player/222889/lucas-acevedo...
# 1786     205186  https://sofifa.com/player/205186/paulo-gazzani...
# 1141     152993  https://sofifa.com/player/152993/renato-civell...
# 519      179847  https://sofifa.com/player/179847/federico-fazi...
#
#          short_name              long_name  age         dob  height_cm  \
# 6542  F. Pellegrino    Fernando Pellegrino   33  1986-03-31        197
# 6067     L. Acevedo          Lucas Acevedo   27  1991-11-08        197
# 1786   P. Gazzaniga   Paulo Dino Gazzaniga   27  1992-01-02        196
# 1141     R. Civelli         Renato Civelli   35  1983-10-14        195
# 519        F. Fazio  Federico Julián Fazio   32  1987-03-17        195
#
#       weight_kg nationality                    club  ...   lwb   ldm   cdm  \
# ...

# %%
arg_sal=arg[['short_name','wage_eur']]
arg_sal.sort_values(by=['wage_eur'],ascending=False)[:5]
arg_sal.head()
# Out:
#      short_name  wage_eur
# 0      L. Messi    565000
# 17    S. Agüero    300000
# 23    P. Dybala    215000
# 66  A. Di María    150000
# 93    M. Icardi    115000

# %%
plt.bar(list(arg_sal['short_name'][:5]),list(arg_sal['wage_eur'][:5]),color=['red','blue','green','grey','pink'])
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_6084\1228138485.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(arg_sal['short_name'][:5]),list(arg_sal['wage_eur'][:5]),color=['red','blue','green','grey','pink'])
# <BarContainer object of 5 artists>

# %%
play_shoo=player[["short_name",'shooting']]
play_shoot=play_shoo.sort_values(by=['shooting'],ascending=False)
play_shoot.head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
plt.figure(figsize=(10,8))
plt.bar(list(play_shoot["short_name"][:5]),list(play_shoot['shooting'][:5]))
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_6084\2102254919.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(play_shoot["short_name"][:5]),list(play_shoot['shooting'][:5]))
# <BarContainer object of 5 artists>

# %%
real_madrid=player[player['club']=='Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
